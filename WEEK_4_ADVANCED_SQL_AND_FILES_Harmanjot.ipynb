# %% [markdown]
# <a href="https://colab.research.google.com/github/hkaur103/COMP-593/blob/main/WEEK_4_ADVANCED_SQL_AND_FILES_Harmanjot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 4 - Advanced SQL / Writing Files
#
# In this week's lab, we are going to expand our Really Simple Social Network by adding another table that will record connections between people! Because after all, what good is a social network if you can't ... be social?
#
# Afterwards, we will be in a good position to run a report on the data, and then we can sell it to marketers for a massive profit! Isn't it great how few people read the terms of service? `/s`

# %% [markdown]
# ## Importing our database
# Since we are using a new colab notebook, we will need to reimport our database. Check your D2L Submission if you didn't keep a copy, you should be able to redownload it there. Run the below code block and the file upload picker will appear, after uploading your Database file, check that it appears in the `Files` tab of colab.
#
# Remember that you may need to update the listings before it will appear.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-acc8cf79-ceaa-41dc-909b-d7f3292aa56a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-acc8cf79-ceaa-41dc-909b-d7f3292aa56a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving harmanDB.db to harmanDB.db

# %% [markdown]
# ## Creating our relationship table
#
# In the code block below, we will be creating a new table in our database for `relationships` with the following parameters:
#
#
# 1.   A primary key column called `id` with the `INTEGER` datatype that is `NOT NULL`
# 2.   A foreign key column called `user_id` that links to the `id` column of the `people` table with the `INTEGER` datatype that is `NOT NULL`
# 3.   Another foreign key column called `friend_id` that also links to the `id` column of the `people` table with the `INTEGER` datatype that is `NOT NULL`
# 4.   A `date_created` table with the `DATE` datatype that is `NOT NULL`
#
# The Below codeblock will get you started:

# %%
import sqlite3

#Retreive the Connection object, rename the file to match your uploaded DB if necessary.
myConnection = sqlite3.connect('harmanDB.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#The Primary Key column has been provided for you,
#Replace '#!...' with the remaining column names, datatypes, and foreign key declarations.
#Use the Lecture notes and the previous lab if you are unsure.
createRelationshipsTable = """CREATE TABLE IF NOT EXISTS relationships (
                          id integer PRIMARY KEY NOT NULL,
                          user_id integer NOT NULL,
                          friend_id integer NOT NULL,
                          FOREIGN KEY (user_id) REFERENCES people (id),
                          FOREIGN KEY (friend_id) REFERENCES people (id)
                        );"""

#Once again, we will execute the query, persist the changes, and close our connection.
myCursor.execute(createRelationshipsTable)
myConnection.commit()
myConnection.close()

# %%
#Retreive the Connection object, rename the file to match your uploaded DB if necessary.
myConnection = sqlite3.connect('harmanDB.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#pragma_table_info is an internal SQLite function that will retun information about a table
myCursor.execute("SELECT group_concat(name, ', ') FROM pragma_table_info('relationships')")
print(myCursor.fetchone())

myConnection.close()
# Out:
# ('id, user_id, friend_id',)

# %% [markdown]
# ## Populating Relationship Data
#
# We're not going to be picky about who knows who - so for the purposes of this lab, we're going to use our own version of an AI matchmaker, the `randrange()` method.
#
# Complete the below codeblock, inserting 1000 new rows into the relationships table.
# Use a random number between `1 - 1000` for the `user_id` and `friend_id` columns. This will link up to the `id` column of the `people` table and effectivly simulate a random network of relationships.
#
# The below code block is purposely sparse, as you should be able to use the patterns you've identified in the previous lab to complete this task.

# %%
import sqlite3
from datetime import datetime #For generating dates and times
from random import randrange #For generating random numbers within a range

#Retreive the Connection object, rename the file to match your uploaded DB if necessary.
myConnection = sqlite3.connect('harmanDB.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#Complete the below query
relationshipsQuery = """INSERT INTO relationships (user_id, friend_id)
                        VALUES (?, ?);"""

for _ in range(1000):
  #Populate the arguments that will be used in the query
   user_id = randrange(1, 1000)

   friend_id = user_id
   while friend_id == user_id:
     friend_id = randrange(1, 1000)

   args = (user_id, friend_id)
  
  #Execute the query
   myCursor.execute(relationshipsQuery, args)

#Commit your changes and close the connection.
myConnection.commit()
myConnection.close()

# %%
import sqlite3
import pprint
#Retreiving the Connection object
myConnection = sqlite3.connect('harmanDB.db')

#Connection object to generate a Cursor object used to run SQL Queries
myCursor = myConnection.cursor()

# statement for output the name of no more than 20 people with a heatmap greater than 1500
selectStatement = """SELECT * FROM relationships
                     LIMIT 20
                     ;"""
 
# executing statement for output
myCursor.execute(selectStatement)
output = myCursor.fetchall()
pprint.pprint(output)

myConnection.close()
# Out:
# [(1, 914, 650),
#  (2, 824, 351),
#  (3, 212, 383),
#  (4, 23, 314),
#  (5, 131, 528),
#  (6, 973, 644),
#  (7, 952, 80),
#  (8, 39, 704),
#  (9, 247, 883),
#  (10, 344, 278),
#  (11, 707, 78),
#  (12, 354, 32),
#  (13, 17, 400),
#  (14, 873, 682),
#  (15, 895, 969),
#  (16, 405, 945),
#  (17, 507, 227),
#  (18, 317, 983),
#  (19, 143, 15),
#  (20, 829, 851)]

# %% [markdown]
# ## Building our Report
#
# Now that our AI Matchmaker has generated our network of relationships, a marketing firm is offering us boatloads of cash for information about the amount of friends the users of our social network have.
#
# The request is to return the name of each user, and the total number of relationships they have made.
#
# If this was explained in awkward pseudo code, it might go something like this:
# ```
# SELECT all relationships
# JOIN them to the people they belong to
# GROUP the results by the person's ID
# return the person's name and COUNT of their relationships
# ```
#
# After you have collected the data, you will need to write it to a `.txt` file.
#
# **Your submission will include the report `.txt` file, the copy of your updated `social_network.db` file, and a link to the colab notebook.**
#
# Look at the aggregate functions from Week 3 and the Join examples from Week 4. There are a few different ways that you can structure a query to reach the correct answer.
#
# **At a minimum, you will need to use a `LEFT JOIN` statement, a `GROUP BY` statement, and a `COUNT()` aggregate function.**
#
# The below code block will get you started:

# %%
from os import name
import sqlite3
from pprint import pprint
#Retreive the Connection object, rename the file to match your uploaded DB if necessary.
myConnection = sqlite3.connect('harmanDB.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#Uncomment the below line after you have determined what the correct mode will be for your file pointer.
#fp = open('report.txt', mode='')

#Complete the below query
query =  """SELECT people.name, COUNT(*)FROM relationships
            JOIN people ON relationships.user_id = people.id
            GROUP BY relationships.user_id
         """

myCursor.execute(query)
results = myCursor.fetchall()
pprint(results)
myConnection.close() 

fp = open('lab4.txt', mode='w')

fp.write
for result in results:
  fp.write(sentence)
  sentence = result[0] + " has " + str(result[1]) + " relationships.\n"
  print(sentence)

fp.close()

  #You will want to write the results to the file pointer here.
  #Use the newline character \n to create a line break in each write() statement.
  #Use print() statements as sanity checks if you are unsure of the integrity of your data.

#Don't forget to close the file pointer after you have finished!
# Out:
# [('Makayla Flores', 1),
#  ('Michelle Rios', 1),
#  ('Martha Olsen', 1),
#  ('Samuel Hoover', 1),
#  ('Nicole Simmons', 2),
#  ('Cheryl Conrad', 1),
#  ('Paul Jordan', 1),
#  ('Sean Peterson', 2),
#  ('Joseph Perez', 3),
#  ('Elizabeth Robbins', 1),
#  ('Lisa Contreras', 1),
#  ('Emma Moore', 2),
#  ('Rebecca Yu', 2),
#  ('Madison Morgan', 1),
#  ('James Melendez', 3),
#  ('Kenneth Cole', 1),
#  ('Virginia Ortiz', 3),
#  ('Tracy Shaffer', 1),
#  ('Cassandra Walker', 1),
#  ('Scott Mccarthy', 2),
#  ('Arthur Snow', 1),
#  ('Jason Lucero', 2),
#  ('Pam Turner', 3),
#  ('Erica Thompson', 2),
#  ('Michelle Allen', 1),
#  ('Bradley Lane', 1),
#  ('Laura Lloyd', 2),
#  ('Bethany Williams', 1),
#  ('Matthew Morgan', 1),
#  ('Cheryl Bass', 1),
#  ('Ryan Berger', 1),
#  ('Lindsey Duarte', 2),
#  ('Rachel Ewing', 1),
#  ('Jordan Garcia', 1),
#  ('Margaret Johnson', 3),
#  ('Elizabeth French', 2),
#  ('Claire Reyes', 1),
#  ('Jonathon Shaw', 1),
#  ('Joseph Rodriguez', 1),
#  ('John Thomas', 1),
#  ('Destiny Turner', 2),
#  ('Courtney Carr', 3),
#  ('Sheri Phillips', 2),
#  ('Melissa Aguilar', 2),
#  ('Veronica Ruiz', 4),
#  ('Timothy Shepard', 2),
#  ('Jennifer Lynch', 3),
#  ('Nancy Stewart', 2),
#  ('Tammy Frazier', 2),
#  ('Jennifer Hart', 2),
#  ('Kelly Brown', 1),
#  ('Rhonda Salazar', 1),
#  ('Luke Bradley', 1),
#  ('Anita Collins', 2),
#  ('Roberto Petersen', 2),
#  ('Gregory Miller', 1),
#  ('Brian Green', 2),
#  ('Margaret Miller', 2),
#  ('Charles Park', 1),
#  ('Benjamin Torres', 1),
#  ('Mr. Stephen Perez', 1),
#  ('Wayne Brown', 1),
#  ('Dana Harvey', 1),
#  ('Marcia Hamilton', 2),
#  ('Erica Andrews', 1),
#  ('Carlos Gray', 1),
#  ('Sara Ward', 2),
#  ('Jake Rogers', 2),
#  ('Thomas Hamilton', 3),
#  ('William Beck', 1),
#  ('Sean Garcia', 4),
#  ('Tracy Patterson', 1),
#  ('William Aguirre', 1),
#  ('John Cole', 1),
#  ('Yvette Thomas', 1),
#  ('Jessica Schmidt', 3),
#  ('Laurie Pena', 2),
#  ('Jerry Brown', 1),
#  ('Rhonda Smith', 2),
#  ('Lauren Cook', 1),
#  ('Sheila Moore', 1),
#  ('Tamara Mathis DVM', 2),
#  ('Tiffany Woods', 2),
#  ('Mitchell Davis', 1),
#  ('Stacie Rivers', 1),
#  ('Nicole Velazquez', 1),
#  ('Isaac Chambers', 1),
#  ('Matthew Olsen', 1),
#  ('John Smith', 1),
#  ('Chris Allen', 2),
#  ('Mark Daniel', 3),
#  ('Brooke Sherman', 1),
#  ('Jacob Hoover', 2),
#  ('Walter Marsh', 2),
#  ('Dr. Kari Meyers MD', 3),
#  ('Brent Alvarez', 1),
#  ('Hannah Gibbs', 2),
#  ('Veronica Ruiz', 1),
#  ('Daniel Brandt', 2),
#  ('Eric Thompson', 1),
#  ('Ray Johnson', 1),
#  ('Adam Salazar', 2),
#  ('Kevin Henderson', 3),
#  ('Mitchell Johnson', 1),
#  ('Curtis Miller', 1),
#  ('Steven Avila', 2),
#  ('Nicole Day', 1),
#  ('Kyle Haas', 1),
#  ('Audrey Garcia', 2),
#  ('Jeffery Foster', 1),
#  ('Martha Bowman', 1),
#  ('Shannon Yoder', 3),
#  ('Jonathan Carroll', 1),
#  ('Francisco Johnson', 1),
#  ('Alexander Collins', 1),
#  ('Jacqueline Terry', 3),
#  ('Cathy Smith', 3),
#  ('Patricia Clay', 2),
#  ('Tammy Rose', 1),
#  ('Tammy Stokes', 3),
#  ('Richard Robinson', 1),
#  ('George Quinn', 1),
#  ('Molly Johnson', 4),
#  ('George Armstrong', 2),
#  ('Carlos Mendoza', 1),
#  ('Leslie Shields', 1),
#  ('Natalie Casey', 2),
#  ('Deborah Mendoza', 1),
#  ('Felicia Jones', 3),
#  ('Javier Anderson', 1),
#  ('Julia Shaw', 1),
#  ('Michael Kennedy', 2),
#  ('Sara Smith', 1),
#  ('Rebecca Williams', 1),
#  ('Laura Vargas', 1),
#  ('Ashley Long', 1),
#  ('Jessica Forbes', 2),
#  ('Erica Gallagher', 1),
#  ('Diane Ho', 1),
#  ('Charles Perez', 3),
#  ('Brian Adams', 1),
#  ('John Daniels', 2),
#  ('Jessica Weiss', 4),
#  ('William Monroe', 1),
#  ('Lisa Brown', 1),
#  ('Todd Howard', 2),
#  ('Nicole Griffin', 4),
#  ('Tyler Daugherty', 1),
#  ('Brittany Barrett DVM', 1),
#  ('Steven Carr', 1),
#  ('Abigail Bishop', 1),
#  ('Joshua Sanders', 4),
#  ('John Pearson', 1),
#  ('Edwin Kim', 1),
#  ('Tiffany Gomez', 2),
#  ('Leslie Myers', 3),
#  ('Lisa Smith', 1),
#  ('James Harrington', 2),
#  ('Caleb Mcdaniel', 1),
#  ('Charles Garcia', 1),
#  ('Mary Neal', 2),
#  ('Todd Hamilton', 1),
#  ('Sharon Thompson', 1),
#  ('Raymond Jackson', 2),
#  ('Stacy Jacobson', 1),
#  ('Ronald Trujillo', 1),
#  ('Mark Lane', 4),
#  ('Vincent Hopkins', 1),
#  ('Matthew Rivera', 1),
#  ('Erica Williams', 1),
#  ('Melinda Martin', 1),
#  ('Elizabeth Morris', 1),
#  ('Christopher Mullins', 3),
#  ('Natasha Baker', 2),
#  ('Margaret Wright', 3),
#  ('Sarah Curtis', 3),
#  ('Emily Suarez', 1),
#  ('Lydia Adams', 2),
#  ('David Gamble', 1),
#  ('Ralph Hunter', 3),
#  ('Christopher Gomez', 2),
#  ('Katherine Davis', 1),
#  ('Jon Russell', 1),
#  ('David Johnson', 3),
#  ('Shannon Johnson', 1),
#  ('John Martinez', 2),
#  ('Jonathan Guerrero', 1),
#  ('Jordan Cole', 3),
#  ('Jordan Odonnell', 1),
#  ('Samantha Ross', 2),
#  ('Phillip Terry', 1),
#  ('Patricia Gibson', 1),
#  ('Stephen Meadows', 1),
#  ('Lisa Griffin', 3),
#  ('Karen Rosario', 1),
#  ('Tracy Freeman', 1),
#  ('Janet Clark', 3),
#  ('Paul Warner', 1),
#  ('Debra Barnes', 2),
#  ('Dawn Jones', 1),
#  ('Thomas Pope', 1),
#  ('Eric Thomas', 3),
#  ('Daniel Smith', 2),
#  ('Matthew Parker', 1),
#  ('Kevin Hill', 2),
#  ('Jeffrey Vega', 2),
#  ('Jesse King', 1),
#  ('Barbara Morrow', 3),
#  ('Jose Anderson', 1),
#  ('Robert Gonzalez', 2),
#  ('Lindsey Carlson', 1),
#  ('Jennifer Mendez', 1),
#  ('Clarence Finley', 2),
#  ('Carl Graham', 1),
#  ('Nicole Park', 1),
#  ('Kayla Logan', 1),
#  ('Bridget Andrews', 1),
#  ('Ruben Valdez', 1),
#  ('Nicole Camacho', 1),
#  ('Ashley English', 1),
#  ('Jennifer Jones', 1),
#  ('Roy Kelley', 2),
#  ('Sara Thomas', 1),
#  ('James Roberts', 2),
#  ('Tina Conway', 1),
#  ('James Bishop', 3),
#  ('Paula Beard', 2),
#  ('Sharon Yates', 1),
#  ('Aaron Harris', 2),
#  ('Sandra Bartlett', 4),
#  ('Jeffrey Johnson', 2),
#  ('Donald Parker', 2),
#  ('Caitlin Crawford', 1),
#  ('Wayne Walker', 1),
#  ('Sara Martinez', 1),
#  ('Cynthia Collier', 1),
#  ('Steven Marshall', 1),
#  ('Heather Cain', 1),
#  ('Brittany Freeman', 2),
#  ('Renee Mccarthy', 4),
#  ('Isaiah Estrada', 1),
#  ('Catherine Shea', 1),
#  ('Richard Parker', 2),
#  ('Christine Hernandez', 1),
#  ('Doris Dudley', 1),
#  ('Chad Brewer', 1),
#  ('Antonio Watkins', 1),
#  ('Kyle Hess', 1),
#  ('Emma Melton', 3),
#  ('Christina Johnson', 3),
#  ('Hector Pierce', 1),
#  ('Tammy Vance', 2),
#  ('Dana Davis', 1),
#  ('Joseph Hernandez', 1),
#  ('Sarah Orr', 4),
#  ('Dennis Owen', 2),
#  ('Barbara Martin', 1),
#  ('Francisco Beard', 2),
#  ('Tracy Nelson', 1),
#  ('Carl Simmons', 1),
#  ('Katelyn Meyer', 1),
#  ('Erik Russo', 3),
#  ('Melinda Rosario', 1),
#  ('Ray Snyder', 1),
#  ('Jennifer Campos', 2),
#  ('Rebecca Baker', 1),
#  ('Todd Lewis', 1),
#  ('Hailey Moore', 2),
#  ('Kevin Pena', 1),
#  ('Jonathan Rogers', 1),
#  ('Philip Montgomery', 1),
#  ('Alec Suarez', 1),
#  ('Mark Daniels', 1),
#  ('Olivia Scott', 1),
#  ('Elizabeth Perez', 1),
#  ('Paul Perkins', 3),
#  ('Christina Huff', 1),
#  ('Cynthia Green', 1),
#  ('Ruben Wright', 2),
#  ('Nancy James', 1),
#  ('Lori Woodard', 2),
#  ('Kimberly Salinas', 1),
#  ('Megan Williams', 1),
#  ('Cynthia Bentley', 1),
#  ('Stephanie Gomez', 3),
#  ('Zachary Gomez', 1),
#  ('James Campbell', 1),
#  ('Sarah Hicks', 2),
#  ('Vanessa Payne', 1),
#  ('Christopher Rivera', 1),
#  ('Susan Mason', 2),
#  ('Mary Mitchell', 2),
#  ('Scott Dunlap', 1),
#  ('Dr. Daniel Garza II', 1),
#  ('Olivia Nguyen', 1),
#  ('Jennifer Scott', 1),
#  ('Kim Gonzalez', 2),
#  ('Samantha Arnold', 1),
#  ('Jennifer Green', 1),
#  ('Jonathan Coleman', 2),
#  ('Debra Cowan', 2),
#  ('Roger Garrett', 1),
#  ('Kayla Washington', 1),
#  ('Ronald Mccarthy', 1),
#  ('Cassandra Ayala', 2),
#  ('James Lewis', 2),
#  ('Charles Clark', 3),
#  ('Brett Jones', 2),
#  ('Hailey Bowen', 2),
#  ('Joshua Stanton', 2),
#  ('Cory Moyer', 3),
#  ('Chloe Mcdonald', 1),
#  ('Amanda Patel', 1),
#  ('Amy Barton', 2),
#  ('Erin Levy', 1),
#  ('Jerome Lee', 1),
#  ('Mark Thomas', 2),
#  ('Sylvia Neal', 1),
#  ('Wayne Harris', 3),
#  ('Carlos Davis', 3),
#  ('Sara Miller', 1),
#  ('James Jones', 1),
#  ('Amber Norton', 2),
#  ('Jeffery Cooper', 1),
#  ('Christopher Holmes', 2),
#  ('Mr. Jerry Wagner', 3),
#  ('Troy Dunn', 1),
#  ('Craig Rhodes', 1),
#  ('Stephen Phillips', 2),
#  ('Diana Gray', 1),
#  ('James Vargas', 1),
#  ('Louis Hawkins', 3),
#  ('Jennifer Brown', 1),
#  ('Michael Cummings', 1),
#  ('Willie Dodson', 2),
#  ('Todd Rivas', 3),
#  ('Pamela Welch', 1),
#  ('Emily Mclaughlin', 2),
#  ('Ann Parks', 1),
#  ('Penny Smith', 2),
#  ('Jill Huynh', 2),
#  ('Jocelyn Sheppard', 2),
#  ('Eric Rogers', 2),
#  ('Preston Jones', 1),
#  ('Phillip Jones', 2),
#  ('Brian Maddox', 2),
#  ('Andrew Wood', 1),
#  ('Dennis Martinez', 2),
#  ('Amber Morrison', 2),
#  ('Julie Burgess', 1),
#  ('Melanie Henderson', 1),
#  ('Samantha Pittman', 1),
#  ('Timothy Walker', 1),
#  ('Renee Torres', 1),
#  ('Katelyn Gould', 1),
#  ('Jeremy Cardenas', 1),
#  ('Michael Brennan', 1),
#  ('Frederick Kennedy', 3),
#  ('Kyle Estrada', 1),
#  ('Tammy Fleming', 1),
#  ('Tanya Chapman', 1),
#  ('Monica Jones', 2),
#  ('Jason Hood', 1),
#  ('Sara Gordon', 1),
#  ('Ryan Davis', 1),
#  ('Jeffery Williams', 1),
#  ('Kevin Brock', 2),
#  ('Samantha Wade', 1),
#  ('Carl Morris DDS', 2),
#  ('Susan Mcmahon', 2),
#  ('Marc Nelson', 1),
#  ('Brandi Martinez', 2),
#  ('Cassandra Cooper', 1),
#  ('Brittany Lee', 1),
#  ('Gabrielle Jackson', 2),
#  ('Jordan Chavez', 2),
#  ('Christopher Maxwell', 1),
#  ('Clifford Huffman', 1),
#  ('Paul Martin', 1),
#  ('Dr. Erika Ortiz', 1),
#  ('Patrick Allen', 1),
#  ('Natasha Gallagher', 4),
#  ('Emily Adams', 1),
#  ('Denise Caldwell', 2),
#  ('Roger Martinez', 1),
#  ('Sierra Carter', 2),
#  ('Alex Patterson', 2),
#  ('Cathy Chung', 2),
#  ('Stephanie Martinez', 1),
#  ('Shane Davis', 1),
#  ('Mario Stone', 3),
#  ('Melissa Martin', 2),
#  ('Renee Hughes', 3),
#  ('John Simmons', 2),
#  ('Emma Gutierrez', 1),
#  ('Travis Bennett', 1),
#  ('Reginald Ramos', 1),
#  ('Shelley Quinn', 1),
#  ('James Guerra', 1),
#  ('Angela Farmer', 1),
#  ('Michael Mcbride', 2),
#  ('Andrew Holmes', 2),
#  ('Riley Blackburn', 1),
#  ('Leslie Haley', 2),
#  ('Cheryl Clark', 4),
#  ('Jeff Campos', 1),
#  ('Jose Deleon', 1),
#  ('Dana Romero', 1),
#  ('Nicole Farmer', 2),
#  ('Michelle Cooper', 1),
#  ('Anthony Dixon', 1),
#  ('Melissa Clark', 1),
#  ('Brian Wells', 1),
#  ('Laura Harris', 4),
#  ('Erica Moore', 2),
#  ('Ryan Wheeler', 3),
#  ('Michael Burns', 3),
#  ('Andrew Smith', 1),
#  ('Stephen Arellano', 1),
#  ('Dr. Jessica Murphy PhD', 1),
#  ('Jeffrey Barnes', 2),
#  ('Shawn Martin', 1),
#  ('Aaron Wilson', 2),
#  ('Michael Thompson', 1),
#  ('Jackson Wood', 1),
#  ('Erin Thomas', 1),
#  ('Megan Wheeler', 2),
#  ('Dawn Harrison', 1),
#  ('Heidi Vega', 2),
#  ('Stacey Lopez', 3),
#  ('Michael Riggs', 1),
#  ('Tracey Gonzalez', 1),
#  ('Priscilla Russo', 1),
#  ('Laura Garcia', 2),
#  ('Mark Shaw', 1),
#  ('Justin Wright', 1),
#  ('Richard Gibson', 1),
#  ('William Barnes', 1),
#  ('Cynthia Powell', 1),
#  ('Nicole Daniels', 2),
#  ('Melanie Nash', 2),
#  ('Erik Solomon', 1),
#  ('George Brooks', 1),
#  ('Terry Jackson', 1),
#  ('Jason Sullivan', 1),
#  ('Rhonda Medina', 1),
#  ('Elizabeth Nelson', 2),
#  ('Christine Obrien', 1),
#  ('Molly Simmons', 2),
#  ('Donald Summers', 2),
#  ('Sally Taylor', 3),
#  ('Brandon Schultz', 2),
#  ('Christopher Mueller', 1),
#  ('Valerie Diaz', 1),
#  ('Michael Thomas', 2),
#  ('Henry Ponce', 1),
#  ('Alicia Anderson', 1),
#  ('Chris Gross', 1),
#  ('Scott White', 1),
#  ('Jessica Tapia', 1),
#  ('Lori Kramer', 3),
#  ('Anthony Green', 3),
#  ('Brooke Hansen', 1),
#  ('Omar Underwood', 2),
#  ('Diana Wright', 1),
#  ('Barbara Wood', 1),
#  ('Veronica Lee', 2),
#  ('Michelle Williams', 1),
#  ('April Cunningham DVM', 1),
#  ('Timothy Patel', 1),
#  ('John Li', 1),
#  ('April Ibarra', 2),
#  ('Brandi Baker', 2),
#  ('Cheryl Gibbs', 1),
#  ('Nicole Arnold', 3),
#  ('Kelly Jones', 1),
#  ('Charles Moore', 1),
#  ('Yolanda Jones', 1),
#  ('Ricky Figueroa', 1),
#  ('Kelly Duran', 1),
#  ('Karen Taylor', 1),
#  ('Brenda Carroll', 1),
#  ('Casey Little', 1),
#  ('Nina Robbins', 1),
#  ('Sarah Moreno DDS', 2),
#  ('Nancy Hodges', 1),
#  ('Cynthia Boyer', 1),
#  ('Justin Blair', 1),
#  ('Duane Medina', 1),
#  ('Melissa Morrison', 2),
#  ('Jessica Zuniga', 3),
#  ('Thomas Tate', 1),
#  ('Michelle Garcia', 2),
#  ('Daniel Goodwin', 1),
#  ('Haley Mora', 1),
#  ('George Huber', 3),
#  ('Kristina Miller', 2),
#  ('Gail Richards', 1),
#  ('Sheena Walker', 1),
#  ('Bryan Flowers', 1),
#  ('Traci Shea', 2),
#  ('Mr. Mark Fox', 2),
#  ('Jimmy Herrera', 1),
#  ('Patricia Lewis', 1),
#  ('Andrew Hunter', 2),
#  ('Taylor Henry', 2),
#  ('Misty Richardson', 3),
#  ('Elizabeth Jones', 1),
#  ('Robin Phillips', 2),
#  ('Paula Nelson', 1),
#  ('Brenda Ford', 3),
#  ('Jay Castro', 2),
#  ('Kimberly Smith', 2),
#  ('Amy Black', 1),
#  ('Jennifer Martin', 2),
#  ('Laura Ochoa', 1),
#  ('Corey Brown', 1),
#  ('Christopher Garza', 3),
#  ('Dr. Kevin Jenkins', 3),
#  ('Amy Townsend', 1),
#  ('Stephanie Riddle', 2),
#  ('Melissa Martin', 1),
#  ('Deborah Stanley', 3),
#  ('Manuel Smith', 1),
#  ('Jeremy Singh', 1),
#  ('Tyrone Barrett', 1),
#  ('William Burke', 1),
#  ('Kendra Watson', 2),
#  ('Crystal Martin', 1),
#  ('Jamie Shaw', 1),
#  ('Anna Vasquez', 2),
#  ('Joseph Sims', 2),
#  ('Troy Marshall', 1),
#  ('Sarah Bates', 1),
#  ('Dana Rocha', 1),
#  ('Joshua Martin', 2),
#  ('Martin Welch', 1),
#  ('Jennifer Gordon', 2),
#  ('Melissa Perry', 1),
#  ('Chad Valdez', 1),
#  ('Christopher Jensen', 1),
#  ('Melissa Sutton', 3),
#  ('Kathleen Davis', 2),
#  ('Mariah Marks', 1),
#  ('Tracy Serrano', 1),
#  ('Timothy Smith', 3),
#  ('Seth Anderson', 1),
#  ('Deanna Douglas', 1),
#  ('Kevin Warren', 1),
#  ('Devin Brown', 2),
#  ('Crystal Johnson', 1),
#  ('Evan Reynolds', 1),
#  ('Erica Alexander', 1),
#  ('Mason Collins', 1),
#  ('Lisa Lucas', 1),
#  ('Jordan Fisher', 3),
#  ('Zachary Williams', 1),
#  ('Robert Davila', 1),
#  ('Elizabeth Petersen', 4),
#  ('Mary Torres', 2),
#  ('Dr. Kristy Austin', 1),
#  ('Jeffrey Austin', 2),
#  ('Melinda Graham', 1),
#  ('Steven Dominguez', 1),
#  ('Robert Evans', 3),
#  ('Joshua Malone', 2),
#  ('Travis Freeman', 1),
#  ('Brandon Davis', 1),
#  ('Kenneth Stark', 2),
#  ('Donna Castro', 5),
#  ('Jerry Taylor', 3),
#  ('Megan Maldonado', 1),
#  ('Cory Velazquez', 1),
#  ('Daniel Harris', 2),
#  ('Loretta Brown', 1),
#  ('Allison Hubbard', 1),
#  ('Richard Carpenter', 1),
#  ('Anne Riley', 1),
#  ('Lindsay Howe', 1),
#  ('Krystal Wells', 2),
#  ('Robert Edwards', 1),
#  ('Keith Castillo', 1),
#  ('Nancy Kelley', 2),
#  ('David Reed', 1),
#  ('Deborah Zavala', 3),
#  ('Scott Anderson', 1),
#  ('Gary Cooke', 2),
#  ('Brianna Lyons', 1),
#  ('Denise Dean', 1),
#  ('Edwin Alvarez', 1),
#  ('Jeffery Smith', 2),
#  ('Angel Wallace', 1),
#  ('Matthew Perez', 3),
#  ('Billy Garner', 1),
#  ('Derrick Willis', 1),
#  ('Michael King', 2),
#  ('Alexander Carr', 1),
#  ('Jesus Bell', 1),
#  ('Dean Zhang', 1),
#  ('Kimberly West', 3),
#  ('Kimberly Johnson', 1),
#  ('Judy Crosby', 2),
#  ('Susan Wagner', 3),
#  ('Ashley Hernandez', 2),
#  ('Daniel Aguilar', 2),
#  ('Jeanne Smith', 3),
#  ('Joshua Jones', 1),
#  ('Charlotte Guzman', 2),
#  ('Ebony Erickson', 3),
#  ('Nicholas Osborn', 2),
#  ('Susan Stone', 1),
#  ('Mark Perez', 1),
#  ('Morgan Brown', 2),
#  ('Rebecca Martinez', 1),
#  ('Melissa Holt', 1),
#  ('Anthony Brown', 2),
#  ('Meredith Mccann', 2),
#  ('Alex Mccormick', 1),
#  ('Isaac Ellis', 1),
#  ('Peter Walker', 1),
#  ('Adrian Miller', 1),
#  ('Deborah Martinez', 1),
#  ('Debra Young', 1),
#  ('Robert Sutton', 1),
#  ('Jorge Sherman', 1),
#  ('Kayla Rollins', 1),
#  ('Anna Myers', 1),
#  ('Kelly Berry', 2),
#  ('Alyssa Rasmussen', 2),
#  ('Lisa Spears', 2),
#  ('Rachel Gordon', 1),
#  ('Courtney Logan', 1),
#  ('Raymond Bishop', 2),
#  ('Michael Dawson', 2),
#  ('Larry Jenkins', 2),
#  ('Amy Bennett', 1),
#  ('David Austin', 1)]
# Makayla Flores has 1 relationships.
#
# Michelle Rios has 1 relationships.
#
# Martha Olsen has 1 relationships.
#
# Samuel Hoover has 1 relationships.
#
# Nicole Simmons has 2 relationships.
#
# Cheryl Conrad has 1 relationships.
#
# Paul Jordan has 1 relationships.
#
# Sean Peterson has 2 relationships.
#
# Joseph Perez has 3 relationships.
#
# Elizabeth Robbins has 1 relationships.
#
# Lisa Contreras has 1 relationships.
#
# Emma Moore has 2 relationships.
#
# Rebecca Yu has 2 relationships.
#
# Madison Morgan has 1 relationships.
#
# James Melendez has 3 relationships.
#
# Kenneth Cole has 1 relationships.
#
# Virginia Ortiz has 3 relationships.
#
# Tracy Shaffer has 1 relationships.
#
# Cassandra Walker has 1 relationships.
#
# Scott Mccarthy has 2 relationships.
#
# Arthur Snow has 1 relationships.
#
# Jason Lucero has 2 relationships.
#
# Pam Turner has 3 relationships.
#
# Erica Thompson has 2 relationships.
#
# Michelle Allen has 1 relationships.
#
# Bradley Lane has 1 relationships.
#
# Laura Lloyd has 2 relationships.
#
# Bethany Williams has 1 relationships.
#
# Matthew Morgan has 1 relationships.
#
# Cheryl Bass has 1 relationships.
#
# Ryan Berger has 1 relationships.
#
# Lindsey Duarte has 2 relationships.
#
# Rachel Ewing has 1 relationships.
#
# Jordan Garcia has 1 relationships.
#
# Margaret Johnson has 3 relationships.
#
# Elizabeth French has 2 relationships.
#
# Claire Reyes has 1 relationships.
#
# Jonathon Shaw has 1 relationships.
#
# Joseph Rodriguez has 1 relationships.
#
# John Thomas has 1 relationships.
#
# Destiny Turner has 2 relationships.
#
# Courtney Carr has 3 relationships.
#
# Sheri Phillips has 2 relationships.
#
# Melissa Aguilar has 2 relationships.
#
# Veronica Ruiz has 4 relationships.
#
# Timothy Shepard has 2 relationships.
#
# Jennifer Lynch has 3 relationships.
#
# Nancy Stewart has 2 relationships.
#
# Tammy Frazier has 2 relationships.
#
# Jennifer Hart has 2 relationships.
#
# Kelly Brown has 1 relationships.
#
# Rhonda Salazar has 1 relationships.
#
# Luke Bradley has 1 relationships.
#
# Anita Collins has 2 relationships.
#
# Roberto Petersen has 2 relationships.
#
# Gregory Miller has 1 relationships.
#
# Brian Green has 2 relationships.
#
# Margaret Miller has 2 relationships.
#
# Charles Park has 1 relationships.
#
# Benjamin Torres has 1 relationships.
#
# Mr. Stephen Perez has 1 relationships.
#
# Wayne Brown has 1 relationships.
#
# Dana Harvey has 1 relationships.
#
# Marcia Hamilton has 2 relationships.
#
# Erica Andrews has 1 relationships.
#
# Carlos Gray has 1 relationships.
#
# Sara Ward has 2 relationships.
#
# Jake Rogers has 2 relationships.
#
# Thomas Hamilton has 3 relationships.
#
# William Beck has 1 relationships.
#
# Sean Garcia has 4 relationships.
#
# Tracy Patterson has 1 relationships.
#
# William Aguirre has 1 relationships.
#
# John Cole has 1 relationships.
#
# Yvette Thomas has 1 relationships.
#
# Jessica Schmidt has 3 relationships.
#
# Laurie Pena has 2 relationships.
#
# Jerry Brown has 1 relationships.
#
# Rhonda Smith has 2 relationships.
#
# Lauren Cook has 1 relationships.
#
# Sheila Moore has 1 relationships.
#
# Tamara Mathis DVM has 2 relationships.
#
# Tiffany Woods has 2 relationships.
#
# Mitchell Davis has 1 relationships.
#
# Stacie Rivers has 1 relationships.
#
# Nicole Velazquez has 1 relationships.
#
# Isaac Chambers has 1 relationships.
#
# Matthew Olsen has 1 relationships.
#
# John Smith has 1 relationships.
#
# Chris Allen has 2 relationships.
#
# Mark Daniel has 3 relationships.
#
# Brooke Sherman has 1 relationships.
#
# Jacob Hoover has 2 relationships.
#
# Walter Marsh has 2 relationships.
#
# Dr. Kari Meyers MD has 3 relationships.
#
# Brent Alvarez has 1 relationships.
#
# Hannah Gibbs has 2 relationships.
#
# Veronica Ruiz has 1 relationships.
#
# Daniel Brandt has 2 relationships.
#
# Eric Thompson has 1 relationships.
#
# Ray Johnson has 1 relationships.
#
# Adam Salazar has 2 relationships.
#
# Kevin Henderson has 3 relationships.
#
# Mitchell Johnson has 1 relationships.
#
# Curtis Miller has 1 relationships.
#
# Steven Avila has 2 relationships.
#
# Nicole Day has 1 relationships.
#
# Kyle Haas has 1 relationships.
#
# Audrey Garcia has 2 relationships.
#
# Jeffery Foster has 1 relationships.
#
# Martha Bowman has 1 relationships.
#
# Shannon Yoder has 3 relationships.
#
# Jonathan Carroll has 1 relationships.
#
# Francisco Johnson has 1 relationships.
#
# Alexander Collins has 1 relationships.
#
# Jacqueline Terry has 3 relationships.
#
# Cathy Smith has 3 relationships.
#
# Patricia Clay has 2 relationships.
#
# Tammy Rose has 1 relationships.
#
# Tammy Stokes has 3 relationships.
#
# Richard Robinson has 1 relationships.
#
# George Quinn has 1 relationships.
#
# Molly Johnson has 4 relationships.
#
# George Armstrong has 2 relationships.
#
# Carlos Mendoza has 1 relationships.
#
# Leslie Shields has 1 relationships.
#
# Natalie Casey has 2 relationships.
#
# Deborah Mendoza has 1 relationships.
#
# Felicia Jones has 3 relationships.
#
# Javier Anderson has 1 relationships.
#
# Julia Shaw has 1 relationships.
#
# Michael Kennedy has 2 relationships.
#
# Sara Smith has 1 relationships.
#
# Rebecca Williams has 1 relationships.
#
# Laura Vargas has 1 relationships.
#
# Ashley Long has 1 relationships.
#
# Jessica Forbes has 2 relationships.
#
# Erica Gallagher has 1 relationships.
#
# Diane Ho has 1 relationships.
#
# Charles Perez has 3 relationships.
#
# Brian Adams has 1 relationships.
#
# John Daniels has 2 relationships.
#
# Jessica Weiss has 4 relationships.
#
# William Monroe has 1 relationships.
#
# Lisa Brown has 1 relationships.
#
# Todd Howard has 2 relationships.
#
# Nicole Griffin has 4 relationships.
#
# Tyler Daugherty has 1 relationships.
#
# Brittany Barrett DVM has 1 relationships.
#
# Steven Carr has 1 relationships.
#
# Abigail Bishop has 1 relationships.
#
# Joshua Sanders has 4 relationships.
#
# John Pearson has 1 relationships.
#
# Edwin Kim has 1 relationships.
#
# Tiffany Gomez has 2 relationships.
#
# Leslie Myers has 3 relationships.
#
# Lisa Smith has 1 relationships.
#
# James Harrington has 2 relationships.
#
# Caleb Mcdaniel has 1 relationships.
#
# Charles Garcia has 1 relationships.
#
# Mary Neal has 2 relationships.
#
# Todd Hamilton has 1 relationships.
#
# Sharon Thompson has 1 relationships.
#
# Raymond Jackson has 2 relationships.
#
# Stacy Jacobson has 1 relationships.
#
# Ronald Trujillo has 1 relationships.
#
# Mark Lane has 4 relationships.
#
# Vincent Hopkins has 1 relationships.
#
# Matthew Rivera has 1 relationships.
#
# Erica Williams has 1 relationships.
#
# Melinda Martin has 1 relationships.
#
# Elizabeth Morris has 1 relationships.
#
# Christopher Mullins has 3 relationships.
#
# Natasha Baker has 2 relationships.
#
# Margaret Wright has 3 relationships.
#
# Sarah Curtis has 3 relationships.
#
# Emily Suarez has 1 relationships.
#
# Lydia Adams has 2 relationships.
#
# David Gamble has 1 relationships.
#
# Ralph Hunter has 3 relationships.
#
# Christopher Gomez has 2 relationships.
#
# Katherine Davis has 1 relationships.
#
# Jon Russell has 1 relationships.
#
# David Johnson has 3 relationships.
#
# Shannon Johnson has 1 relationships.
#
# John Martinez has 2 relationships.
#
# Jonathan Guerrero has 1 relationships.
#
# Jordan Cole has 3 relationships.
#
# Jordan Odonnell has 1 relationships.
#
# Samantha Ross has 2 relationships.
#
# Phillip Terry has 1 relationships.
#
# Patricia Gibson has 1 relationships.
#
# Stephen Meadows has 1 relationships.
#
# Lisa Griffin has 3 relationships.
#
# Karen Rosario has 1 relationships.
#
# Tracy Freeman has 1 relationships.
#
# Janet Clark has 3 relationships.
#
# Paul Warner has 1 relationships.
#
# Debra Barnes has 2 relationships.
#
# Dawn Jones has 1 relationships.
#
# Thomas Pope has 1 relationships.
#
# Eric Thomas has 3 relationships.
#
# Daniel Smith has 2 relationships.
#
# Matthew Parker has 1 relationships.
#
# Kevin Hill has 2 relationships.
#
# Jeffrey Vega has 2 relationships.
#
# Jesse King has 1 relationships.
#
# Barbara Morrow has 3 relationships.
#
# Jose Anderson has 1 relationships.
#
# Robert Gonzalez has 2 relationships.
#
# Lindsey Carlson has 1 relationships.
#
# Jennifer Mendez has 1 relationships.
#
# Clarence Finley has 2 relationships.
#
# Carl Graham has 1 relationships.
#
# Nicole Park has 1 relationships.
#
# Kayla Logan has 1 relationships.
#
# Bridget Andrews has 1 relationships.
#
# Ruben Valdez has 1 relationships.
#
# Nicole Camacho has 1 relationships.
#
# Ashley English has 1 relationships.
#
# Jennifer Jones has 1 relationships.
#
# Roy Kelley has 2 relationships.
#
# Sara Thomas has 1 relationships.
#
# James Roberts has 2 relationships.
#
# Tina Conway has 1 relationships.
#
# James Bishop has 3 relationships.
#
# Paula Beard has 2 relationships.
#
# Sharon Yates has 1 relationships.
#
# Aaron Harris has 2 relationships.
#
# Sandra Bartlett has 4 relationships.
#
# Jeffrey Johnson has 2 relationships.
#
# Donald Parker has 2 relationships.
#
# Caitlin Crawford has 1 relationships.
#
# Wayne Walker has 1 relationships.
#
# Sara Martinez has 1 relationships.
#
# Cynthia Collier has 1 relationships.
#
# Steven Marshall has 1 relationships.
#
# Heather Cain has 1 relationships.
#
# Brittany Freeman has 2 relationships.
#
# Renee Mccarthy has 4 relationships.
#
# Isaiah Estrada has 1 relationships.
#
# Catherine Shea has 1 relationships.
#
# Richard Parker has 2 relationships.
#
# Christine Hernandez has 1 relationships.
#
# Doris Dudley has 1 relationships.
#
# Chad Brewer has 1 relationships.
#
# Antonio Watkins has 1 relationships.
#
# Kyle Hess has 1 relationships.
#
# Emma Melton has 3 relationships.
#
# Christina Johnson has 3 relationships.
#
# Hector Pierce has 1 relationships.
#
# Tammy Vance has 2 relationships.
#
# Dana Davis has 1 relationships.
#
# Joseph Hernandez has 1 relationships.
#
# Sarah Orr has 4 relationships.
#
# Dennis Owen has 2 relationships.
#
# Barbara Martin has 1 relationships.
#
# Francisco Beard has 2 relationships.
#
# Tracy Nelson has 1 relationships.
#
# Carl Simmons has 1 relationships.
#
# Katelyn Meyer has 1 relationships.
#
# Erik Russo has 3 relationships.
#
# Melinda Rosario has 1 relationships.
#
# Ray Snyder has 1 relationships.
#
# Jennifer Campos has 2 relationships.
#
# Rebecca Baker has 1 relationships.
#
# Todd Lewis has 1 relationships.
#
# Hailey Moore has 2 relationships.
#
# Kevin Pena has 1 relationships.
#
# Jonathan Rogers has 1 relationships.
#
# Philip Montgomery has 1 relationships.
#
# Alec Suarez has 1 relationships.
#
# Mark Daniels has 1 relationships.
#
# Olivia Scott has 1 relationships.
#
# Elizabeth Perez has 1 relationships.
#
# Paul Perkins has 3 relationships.
#
# Christina Huff has 1 relationships.
#
# Cynthia Green has 1 relationships.
#
# Ruben Wright has 2 relationships.
#
# Nancy James has 1 relationships.
#
# Lori Woodard has 2 relationships.
#
# Kimberly Salinas has 1 relationships.
#
# Megan Williams has 1 relationships.
#
# Cynthia Bentley has 1 relationships.
#
# Stephanie Gomez has 3 relationships.
#
# Zachary Gomez has 1 relationships.
#
# James Campbell has 1 relationships.
#
# Sarah Hicks has 2 relationships.
#
# Vanessa Payne has 1 relationships.
#
# Christopher Rivera has 1 relationships.
#
# Susan Mason has 2 relationships.
#
# Mary Mitchell has 2 relationships.
#
# Scott Dunlap has 1 relationships.
#
# Dr. Daniel Garza II has 1 relationships.
#
# Olivia Nguyen has 1 relationships.
#
# Jennifer Scott has 1 relationships.
#
# Kim Gonzalez has 2 relationships.
#
# Samantha Arnold has 1 relationships.
#
# Jennifer Green has 1 relationships.
#
# Jonathan Coleman has 2 relationships.
#
# Debra Cowan has 2 relationships.
#
# Roger Garrett has 1 relationships.
#
# Kayla Washington has 1 relationships.
#
# Ronald Mccarthy has 1 relationships.
#
# Cassandra Ayala has 2 relationships.
#
# James Lewis has 2 relationships.
#
# Charles Clark has 3 relationships.
#
# Brett Jones has 2 relationships.
#
# Hailey Bowen has 2 relationships.
#
# Joshua Stanton has 2 relationships.
#
# Cory Moyer has 3 relationships.
#
# Chloe Mcdonald has 1 relationships.
#
# Amanda Patel has 1 relationships.
#
# Amy Barton has 2 relationships.
#
# Erin Levy has 1 relationships.
#
# Jerome Lee has 1 relationships.
#
# Mark Thomas has 2 relationships.
#
# Sylvia Neal has 1 relationships.
#
# Wayne Harris has 3 relationships.
#
# Carlos Davis has 3 relationships.
#
# Sara Miller has 1 relationships.
#
# James Jones has 1 relationships.
#
# Amber Norton has 2 relationships.
#
# Jeffery Cooper has 1 relationships.
#
# Christopher Holmes has 2 relationships.
#
# Mr. Jerry Wagner has 3 relationships.
#
# Troy Dunn has 1 relationships.
#
# Craig Rhodes has 1 relationships.
#
# Stephen Phillips has 2 relationships.
#
# Diana Gray has 1 relationships.
#
# James Vargas has 1 relationships.
#
# Louis Hawkins has 3 relationships.
#
# Jennifer Brown has 1 relationships.
#
# Michael Cummings has 1 relationships.
#
# Willie Dodson has 2 relationships.
#
# Todd Rivas has 3 relationships.
#
# Pamela Welch has 1 relationships.
#
# Emily Mclaughlin has 2 relationships.
#
# Ann Parks has 1 relationships.
#
# Penny Smith has 2 relationships.
#
# Jill Huynh has 2 relationships.
#
# Jocelyn Sheppard has 2 relationships.
#
# Eric Rogers has 2 relationships.
#
# Preston Jones has 1 relationships.
#
# Phillip Jones has 2 relationships.
#
# Brian Maddox has 2 relationships.
#
# Andrew Wood has 1 relationships.
#
# Dennis Martinez has 2 relationships.
#
# Amber Morrison has 2 relationships.
#
# Julie Burgess has 1 relationships.
#
# Melanie Henderson has 1 relationships.
#
# Samantha Pittman has 1 relationships.
#
# Timothy Walker has 1 relationships.
#
# Renee Torres has 1 relationships.
#
# Katelyn Gould has 1 relationships.
#
# Jeremy Cardenas has 1 relationships.
#
# Michael Brennan has 1 relationships.
#
# Frederick Kennedy has 3 relationships.
#
# Kyle Estrada has 1 relationships.
#
# Tammy Fleming has 1 relationships.
#
# Tanya Chapman has 1 relationships.
#
# Monica Jones has 2 relationships.
#
# Jason Hood has 1 relationships.
#
# Sara Gordon has 1 relationships.
#
# Ryan Davis has 1 relationships.
#
# Jeffery Williams has 1 relationships.
#
# Kevin Brock has 2 relationships.
#
# Samantha Wade has 1 relationships.
#
# Carl Morris DDS has 2 relationships.
#
# Susan Mcmahon has 2 relationships.
#
# Marc Nelson has 1 relationships.
#
# Brandi Martinez has 2 relationships.
#
# Cassandra Cooper has 1 relationships.
#
# Brittany Lee has 1 relationships.
#
# Gabrielle Jackson has 2 relationships.
#
# Jordan Chavez has 2 relationships.
#
# Christopher Maxwell has 1 relationships.
#
# Clifford Huffman has 1 relationships.
#
# Paul Martin has 1 relationships.
#
# Dr. Erika Ortiz has 1 relationships.
#
# Patrick Allen has 1 relationships.
#
# Natasha Gallagher has 4 relationships.
#
# Emily Adams has 1 relationships.
#
# Denise Caldwell has 2 relationships.
#
# Roger Martinez has 1 relationships.
#
# Sierra Carter has 2 relationships.
#
# Alex Patterson has 2 relationships.
#
# Cathy Chung has 2 relationships.
#
# Stephanie Martinez has 1 relationships.
#
# Shane Davis has 1 relationships.
#
# Mario Stone has 3 relationships.
#
# Melissa Martin has 2 relationships.
#
# Renee Hughes has 3 relationships.
#
# John Simmons has 2 relationships.
#
# Emma Gutierrez has 1 relationships.
#
# Travis Bennett has 1 relationships.
#
# Reginald Ramos has 1 relationships.
#
# Shelley Quinn has 1 relationships.
#
# James Guerra has 1 relationships.
#
# Angela Farmer has 1 relationships.
#
# Michael Mcbride has 2 relationships.
#
# Andrew Holmes has 2 relationships.
#
# Riley Blackburn has 1 relationships.
#
# Leslie Haley has 2 relationships.
#
# Cheryl Clark has 4 relationships.
#
# Jeff Campos has 1 relationships.
#
# Jose Deleon has 1 relationships.
#
# Dana Romero has 1 relationships.
#
# Nicole Farmer has 2 relationships.
#
# Michelle Cooper has 1 relationships.
#
# Anthony Dixon has 1 relationships.
#
# Melissa Clark has 1 relationships.
#
# Brian Wells has 1 relationships.
#
# Laura Harris has 4 relationships.
#
# Erica Moore has 2 relationships.
#
# Ryan Wheeler has 3 relationships.
#
# Michael Burns has 3 relationships.
#
# Andrew Smith has 1 relationships.
#
# Stephen Arellano has 1 relationships.
#
# Dr. Jessica Murphy PhD has 1 relationships.
#
# Jeffrey Barnes has 2 relationships.
#
# Shawn Martin has 1 relationships.
#
# Aaron Wilson has 2 relationships.
#
# Michael Thompson has 1 relationships.
#
# Jackson Wood has 1 relationships.
#
# Erin Thomas has 1 relationships.
#
# Megan Wheeler has 2 relationships.
#
# Dawn Harrison has 1 relationships.
#
# Heidi Vega has 2 relationships.
#
# Stacey Lopez has 3 relationships.
#
# Michael Riggs has 1 relationships.
#
# Tracey Gonzalez has 1 relationships.
#
# Priscilla Russo has 1 relationships.
#
# Laura Garcia has 2 relationships.
#
# Mark Shaw has 1 relationships.
#
# Justin Wright has 1 relationships.
#
# Richard Gibson has 1 relationships.
#
# William Barnes has 1 relationships.
#
# Cynthia Powell has 1 relationships.
#
# Nicole Daniels has 2 relationships.
#
# Melanie Nash has 2 relationships.
#
# Erik Solomon has 1 relationships.
#
# George Brooks has 1 relationships.
#
# Terry Jackson has 1 relationships.
#
# Jason Sullivan has 1 relationships.
#
# Rhonda Medina has 1 relationships.
#
# Elizabeth Nelson has 2 relationships.
#
# Christine Obrien has 1 relationships.
#
# Molly Simmons has 2 relationships.
#
# Donald Summers has 2 relationships.
#
# Sally Taylor has 3 relationships.
#
# Brandon Schultz has 2 relationships.
#
# Christopher Mueller has 1 relationships.
#
# Valerie Diaz has 1 relationships.
#
# Michael Thomas has 2 relationships.
#
# Henry Ponce has 1 relationships.
#
# Alicia Anderson has 1 relationships.
#
# Chris Gross has 1 relationships.
#
# Scott White has 1 relationships.
#
# Jessica Tapia has 1 relationships.
#
# Lori Kramer has 3 relationships.
#
# Anthony Green has 3 relationships.
#
# Brooke Hansen has 1 relationships.
#
# Omar Underwood has 2 relationships.
#
# Diana Wright has 1 relationships.
#
# Barbara Wood has 1 relationships.
#
# Veronica Lee has 2 relationships.
#
# Michelle Williams has 1 relationships.
#
# April Cunningham DVM has 1 relationships.
#
# Timothy Patel has 1 relationships.
#
# John Li has 1 relationships.
#
# April Ibarra has 2 relationships.
#
# Brandi Baker has 2 relationships.
#
# Cheryl Gibbs has 1 relationships.
#
# Nicole Arnold has 3 relationships.
#
# Kelly Jones has 1 relationships.
#
# Charles Moore has 1 relationships.
#
# Yolanda Jones has 1 relationships.
#
# Ricky Figueroa has 1 relationships.
#
# Kelly Duran has 1 relationships.
#
# Karen Taylor has 1 relationships.
#
# Brenda Carroll has 1 relationships.
#
# Casey Little has 1 relationships.
#
# Nina Robbins has 1 relationships.
#
# Sarah Moreno DDS has 2 relationships.
#
# Nancy Hodges has 1 relationships.
#
# Cynthia Boyer has 1 relationships.
#
# Justin Blair has 1 relationships.
#
# Duane Medina has 1 relationships.
#
# Melissa Morrison has 2 relationships.
#
# Jessica Zuniga has 3 relationships.
#
# Thomas Tate has 1 relationships.
#
# Michelle Garcia has 2 relationships.
#
# Daniel Goodwin has 1 relationships.
#
# Haley Mora has 1 relationships.
#
# George Huber has 3 relationships.
#
# Kristina Miller has 2 relationships.
#
# Gail Richards has 1 relationships.
#
# Sheena Walker has 1 relationships.
#
# Bryan Flowers has 1 relationships.
#
# Traci Shea has 2 relationships.
#
# Mr. Mark Fox has 2 relationships.
#
# Jimmy Herrera has 1 relationships.
#
# Patricia Lewis has 1 relationships.
#
# Andrew Hunter has 2 relationships.
#
# Taylor Henry has 2 relationships.
#
# Misty Richardson has 3 relationships.
#
# Elizabeth Jones has 1 relationships.
#
# Robin Phillips has 2 relationships.
#
# Paula Nelson has 1 relationships.
#
# Brenda Ford has 3 relationships.
#
# Jay Castro has 2 relationships.
#
# Kimberly Smith has 2 relationships.
#
# Amy Black has 1 relationships.
#
# Jennifer Martin has 2 relationships.
#
# Laura Ochoa has 1 relationships.
#
# Corey Brown has 1 relationships.
#
# Christopher Garza has 3 relationships.
#
# Dr. Kevin Jenkins has 3 relationships.
#
# Amy Townsend has 1 relationships.
#
# Stephanie Riddle has 2 relationships.
#
# Melissa Martin has 1 relationships.
#
# Deborah Stanley has 3 relationships.
#
# Manuel Smith has 1 relationships.
#
# Jeremy Singh has 1 relationships.
#
# Tyrone Barrett has 1 relationships.
#
# William Burke has 1 relationships.
#
# Kendra Watson has 2 relationships.
#
# Crystal Martin has 1 relationships.
#
# Jamie Shaw has 1 relationships.
#
# Anna Vasquez has 2 relationships.
#
# Joseph Sims has 2 relationships.
#
# Troy Marshall has 1 relationships.
#
# Sarah Bates has 1 relationships.
#
# Dana Rocha has 1 relationships.
#
# Joshua Martin has 2 relationships.
#
# Martin Welch has 1 relationships.
#
# Jennifer Gordon has 2 relationships.
#
# Melissa Perry has 1 relationships.
#
# Chad Valdez has 1 relationships.
#
# Christopher Jensen has 1 relationships.
#
# Melissa Sutton has 3 relationships.
#
# Kathleen Davis has 2 relationships.
#
# Mariah Marks has 1 relationships.
#
# Tracy Serrano has 1 relationships.
#
# Timothy Smith has 3 relationships.
#
# Seth Anderson has 1 relationships.
#
# Deanna Douglas has 1 relationships.
#
# Kevin Warren has 1 relationships.
#
# Devin Brown has 2 relationships.
#
# Crystal Johnson has 1 relationships.
#
# Evan Reynolds has 1 relationships.
#
# Erica Alexander has 1 relationships.
#
# Mason Collins has 1 relationships.
#
# Lisa Lucas has 1 relationships.
#
# Jordan Fisher has 3 relationships.
#
# Zachary Williams has 1 relationships.
#
# Robert Davila has 1 relationships.
#
# Elizabeth Petersen has 4 relationships.
#
# Mary Torres has 2 relationships.
#
# Dr. Kristy Austin has 1 relationships.
#
# Jeffrey Austin has 2 relationships.
#
# Melinda Graham has 1 relationships.
#
# Steven Dominguez has 1 relationships.
#
# Robert Evans has 3 relationships.
#
# Joshua Malone has 2 relationships.
#
# Travis Freeman has 1 relationships.
#
# Brandon Davis has 1 relationships.
#
# Kenneth Stark has 2 relationships.
#
# Donna Castro has 5 relationships.
#
# Jerry Taylor has 3 relationships.
#
# Megan Maldonado has 1 relationships.
#
# Cory Velazquez has 1 relationships.
#
# Daniel Harris has 2 relationships.
#
# Loretta Brown has 1 relationships.
#
# Allison Hubbard has 1 relationships.
#
# Richard Carpenter has 1 relationships.
#
# Anne Riley has 1 relationships.
#
# Lindsay Howe has 1 relationships.
#
# Krystal Wells has 2 relationships.
#
# Robert Edwards has 1 relationships.
#
# Keith Castillo has 1 relationships.
#
# Nancy Kelley has 2 relationships.
#
# David Reed has 1 relationships.
#
# Deborah Zavala has 3 relationships.
#
# Scott Anderson has 1 relationships.
#
# Gary Cooke has 2 relationships.
#
# Brianna Lyons has 1 relationships.
#
# Denise Dean has 1 relationships.
#
# Edwin Alvarez has 1 relationships.
#
# Jeffery Smith has 2 relationships.
#
# Angel Wallace has 1 relationships.
#
# Matthew Perez has 3 relationships.
#
# Billy Garner has 1 relationships.
#
# Derrick Willis has 1 relationships.
#
# Michael King has 2 relationships.
#
# Alexander Carr has 1 relationships.
#
# Jesus Bell has 1 relationships.
#
# Dean Zhang has 1 relationships.
#
# Kimberly West has 3 relationships.
#
# Kimberly Johnson has 1 relationships.
#
# Judy Crosby has 2 relationships.
#
# Susan Wagner has 3 relationships.
#
# Ashley Hernandez has 2 relationships.
#
# Daniel Aguilar has 2 relationships.
#
# Jeanne Smith has 3 relationships.
#
# Joshua Jones has 1 relationships.
#
# Charlotte Guzman has 2 relationships.
#
# Ebony Erickson has 3 relationships.
#
# Nicholas Osborn has 2 relationships.
#
# Susan Stone has 1 relationships.
#
# Mark Perez has 1 relationships.
#
# Morgan Brown has 2 relationships.
#
# Rebecca Martinez has 1 relationships.
#
# Melissa Holt has 1 relationships.
#
# Anthony Brown has 2 relationships.
#
# Meredith Mccann has 2 relationships.
#
# Alex Mccormick has 1 relationships.
#
# Isaac Ellis has 1 relationships.
#
# Peter Walker has 1 relationships.
#
# Adrian Miller has 1 relationships.
#
# Deborah Martinez has 1 relationships.
#
# Debra Young has 1 relationships.
#
# Robert Sutton has 1 relationships.
#
# Jorge Sherman has 1 relationships.
#
# Kayla Rollins has 1 relationships.
#
# Anna Myers has 1 relationships.
#
# Kelly Berry has 2 relationships.
#
# Alyssa Rasmussen has 2 relationships.
#
# Lisa Spears has 2 relationships.
#
# Rachel Gordon has 1 relationships.
#
# Courtney Logan has 1 relationships.
#
# Raymond Bishop has 2 relationships.
#
# Michael Dawson has 2 relationships.
#
# Larry Jenkins has 2 relationships.
#
# Amy Bennett has 1 relationships.
#
# David Austin has 1 relationships.

# %% [markdown]
# ### Challenge: Write a CSV file
#
# **This challenge isn't for extra marks, it's an opportunity for you to engage in some self guided discovery, only if you feel like it, and only if you have time.**
#
# If you want to challenge yourself, alter the report so that it conforms with the `.csv` file type. There are a number of ways to do this, you can use the `Pandas` module, the `csv` module, or manually.
